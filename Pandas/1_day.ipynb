# %%
import pandas as pd
import matplotlib.pyplot as plt # matplotli library for data visulization in python
import numpy as np
list1 = [32,62,14,69,90,13]
df = pd.DataFrame(list1)
print(df)
# Out:
#     0
# 0  32
# 1  62
# 2  14
# 3  69
# 4  90
# 5  13

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt;
df=pd.DataFrame({"Name":[
    "Ajay Chauhan",
    "Akash Chauhan",
    "Ravi Yadav"
],"Age":[
    25,36,20
],"Sex":[
    "Male",
    "Male",
    "Male"
],"id":[1,2,5]})
# print(df)
# df.plot();
df["Age"].plot()
df["Age"].median()
# Out:
# 25.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = {
      "Name": ["Jai","Prince","Deepak","Anuj"],
      "Age" : [42,62,15,24],
      "Address": ["Delhi","Kanpur","Uttar Pradesh","Pune"],
      "Qualification": ["B.tech","M.A","BSC","MCA"]
}
df = pd.DataFrame(data)
print(df[["Name","Qualification","Age"]])
# Out:
#      Name Qualification  Age
# 0     Jai        B.tech   42
# 1  Prince           M.A   62
# 2  Deepak           BSC   15
# 3    Anuj           MCA   24
